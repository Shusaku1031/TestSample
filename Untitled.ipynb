# %%
import json
import numpy as np
import cv2
import matplotlib.pyplot as plt
import random
import base64

from labelme import PY2,QT4,utils

# %%
with open("141.json","r") as f:
    content = json.load(f)

# %%
content.keys()
# Out:
# dict_keys(['flags', 'fillColor', 'imageWidth', 'imageHeight', 'lineColor', 'shapes', 'imageData', 'version', 'imagePath'])

# %%
content["imageData"]
# Out:
# '...'

# %%
dec_file = base64.b64decode(content["imageData"])

# %%
with open("141.json","rb" if PY2 else "r") as f:
    data = json.load(f)
if data['imageData'] is not None:
    imageData = base64.b64decode(data['imageData'])
    if PY2 and QT4:
        imageData = utils.img_data_png_data(imageData)

# %%
plt.imshow(imageData)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-76-6aed620de912> in <module>()
# ----> 1 plt.imshow(imageData)
#
# c:\miniconda3\envs\env01\lib\site-packages\matplotlib\pyplot.py in imshow(X, cmap, norm, aspect, interpolation, alpha, vmin, vmax, origin, extent, shape, filternorm, filterrad, imlim, resample, url, data, **kwargs)
#    2697         filternorm=filternorm, filterrad=filterrad, imlim=imlim,
#    2698         resample=resample, url=url, **({"data": data} if data is not
# -> 2699         None else {}), **kwargs)
#    2700     sci(__ret)
#    2701     return __ret
#
# c:\miniconda3\envs\env01\lib\site-packages\matplotlib\__init__.py in inner(ax, data, *args, **kwargs)
#    1808                         "the Matplotlib list!)" % (label_namer, func.__name__),
#    1809                         RuntimeWarning, stacklevel=2)
# ...

# %%
im = cv2.imread("141.jpg")
for i in range(len(content["shapes"])):
    arr = np.array(content["shapes"][i]["points"])
    arr2 = []
    for a in arr:
        x = int(round(a[0]))
        y = int(round(a[1]))
        arr2.append([x,y])
    arr2 = np.array(arr2)
    
    r = random.randint(0,255)
    b = random.randint(0,255)
    g = random.randint(0,255)
    
    cv2.fillConvexPoly(im,points=arr2,color=(r,g,b))
    
plt.imshow(im)
